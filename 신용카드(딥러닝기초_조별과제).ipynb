# %% [markdown]
# <a href="https://colab.research.google.com/github/zzickso/DeepLearning/blob/main/%EC%8B%A0%EC%9A%A9%EC%B9%B4%EB%93%9C(%EB%94%A5%EB%9F%AC%EB%8B%9D%EA%B8%B0%EC%B4%88_%EC%A1%B0%EB%B3%84%EA%B3%BC%EC%A0%9C).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
# 코드 내부에 한글을 사용가능 하게 해주는 부분입니다.

# pandas 라이브러리를 불러옵니다.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 딥러닝을 구동하는 데 필요한 케라스 함수를 불러옵니다.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# 필요한 라이브러리를 불러옵니다.
import numpy as np
import tensorflow as tf

# %%
df = pd.read_csv('/content/drive/MyDrive/test/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# 데이터 확인 용
# for data in df.values:
#     print(type(data))

# %% [markdown]
# ## Amount normalization append
#
# **아 그렇게 살지 마시라고요**<br>
# **말을 똑바로 하셨어야죠!!**

# %%
class_list = df.values[:,-1]
df['normAmount'] = df['Amount']
df = df.drop(columns=['Class'])
df
# Out:
#             Time         V1         V2  ...       V28  Amount  normAmount
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      149.62
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69        2.69
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      378.66
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      123.50
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99       69.99
# ...          ...        ...        ...  ...       ...     ...         ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77        0.77
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79       24.79
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88       67.88
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00       10.00
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      217.00
#
# [284807 rows x 31 columns]

# %%
print(class_list)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
amount = []
for data in df.values:
    amount.append([data[-1]])
# amount = np.array(amount)

print(len(amount))
print(type(amount))
# print(amount)
# Out:
# 284807
# <class 'list'>

# %% [markdown]
# Amount Normalization 진행

# %% [markdown]
# <h1>Min-Max Scaler를 사용하였고 => Amount에 적용<br>
# Z score Scaler => V1 ~ V28까지 이미 적용 되어있는 것.</h1>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
print(scaler.fit(amount))
norm_amount = scaler.transform(amount).flatten() # ==> np.reshape(-1)
print(norm_amount[0])
print(amount[0])
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))
# 0.005823793086804956
# [149.62]

# %% [markdown]
# 데이터에 추가.

# %%
for index, data in enumerate(df.values):
#     print(index)
    data[-1] = norm_amount[index]

df
# Out:
#             Time         V1         V2  ...       V28  Amount  normAmount
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62    0.005824
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69    0.000105
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66    0.014739
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50    0.004807
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99    0.002724
# ...          ...        ...        ...  ...       ...     ...         ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77    0.000030
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79    0.000965
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88    0.002642
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00    0.000389
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00    0.008446
#
# [284807 rows x 31 columns]

# %% [markdown]
# class_list : 라벨들.<br>
# df : 정규화까지 완료된 데이터들.

# %%
df['Class'] = df['normAmount']

# %%
for index, data in enumerate(df.values):
    data[-1] = class_list[index]

df
# Out:
#             Time         V1         V2  ...  Amount  normAmount  Class
# 0            0.0  -1.359807  -0.072781  ...  149.62    0.005824    0.0
# 1            0.0   1.191857   0.266151  ...    2.69    0.000105    0.0
# 2            1.0  -1.358354  -1.340163  ...  378.66    0.014739    0.0
# 3            1.0  -0.966272  -0.185226  ...  123.50    0.004807    0.0
# 4            2.0  -1.158233   0.877737  ...   69.99    0.002724    0.0
# ...          ...        ...        ...  ...     ...         ...    ...
# 284802  172786.0 -11.881118  10.071785  ...    0.77    0.000030    0.0
# 284803  172787.0  -0.732789  -0.055080  ...   24.79    0.000965    0.0
# 284804  172788.0   1.919565  -0.301254  ...   67.88    0.002642    0.0
# 284805  172788.0  -0.240440   0.530483  ...   10.00    0.000389    0.0
# 284806  172792.0  -0.533413  -0.189733  ...  217.00    0.008446    0.0
#
# [284807 rows x 32 columns]

# %% [markdown]
# **데이터 셔플**<br>

# %% [markdown]
# 암호 -> 123 -> 다음번에 돌릴때도 123해놓으면 똑같은 값들이 나온다

# %%
df.head()
# Out:
#    Time        V1        V2        V3  ...       V28  Amount  normAmount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ... -0.021053  149.62    0.005824    0.0
# 1   0.0  1.191857  0.266151  0.166480  ...  0.014724    2.69    0.000105    0.0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.059752  378.66    0.014739    0.0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.061458  123.50    0.004807    0.0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.215153   69.99    0.002724    0.0
#
# [5 rows x 32 columns]

# %%
data_shuffled=df.sample(frac=1,random_state = 123).reset_index(drop=True) # 암호 -> 123
data_shuffled.head()
# Out:
#        Time        V1        V2        V3  ...       V28  Amount  normAmount  Class
# 0   54992.0 -0.623235  1.097949  0.748810  ...  0.089418   50.00    0.001946    0.0
# 1  145983.0  2.155748 -0.998223 -1.158978  ... -0.053375   58.00    0.002258    0.0
# 2  142073.0  1.614893 -0.194953 -2.050402  ... -0.003519  198.00    0.007707    0.0
# 3  132462.0  1.908756 -2.517443  0.277391  ... -0.036551   82.00    0.003192    0.0
# 4  119001.0  2.120853 -1.048240 -1.895990  ... -0.074845   93.75    0.003649    0.0
#
# [5 rows x 32 columns]

# %%
class_list = data_shuffled.values[:,-1]
data_shuffled = data_shuffled.drop(columns=['Amount','Class'])
print(class_list)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
data_shuffled.head()
# Out:
#        Time        V1        V2  ...       V27       V28  normAmount
# 0   54992.0 -0.623235  1.097949  ...  0.023302  0.089418    0.001946
# 1  145983.0  2.155748 -0.998223  ... -0.006350 -0.053375    0.002258
# 2  142073.0  1.614893 -0.194953  ... -0.023202 -0.003519    0.007707
# 3  132462.0  1.908756 -2.517443  ...  0.147579 -0.036551    0.003192
# 4  119001.0  2.120853 -1.048240  ... -0.057106 -0.074845    0.003649
#
# [5 rows x 30 columns]

# %% [markdown]
# 학습 데이터셋

# %%
x = data_shuffled.values
y = class_list
print(x.shape)
# x_train => 
# x_test =>
# Out:
# (284807, 30)

# %% [markdown]
# 모델링

# %%
model = Sequential()
model.add(Dense(250, input_dim=30, activation='relu' ))
model.add(Dense(124, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(62, activation='relu'))
model.add(Dense(31, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 250)               7750
# _________________________________________________________________
# dense_1 (Dense)              (None, 124)               31124
# _________________________________________________________________
# dropout (Dropout)            (None, 124)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 62)                7750
# _________________________________________________________________
# dense_3 (Dense)              (None, 31)                1953
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 32
# =================================================================
# Total params: 48,609
# Trainable params: 48,609
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# 학습 진행

# %%
# 모델을 실행합니다.
history_1 = model.fit(x, y, epochs=5, batch_size=100) # batch_size
# Out:
# Epoch 1/5
# 2849/2849 [==============================] - 9s 3ms/step - loss: 17.3999 - accuracy: 0.9923
# Epoch 2/5
# 2849/2849 [==============================] - 9s 3ms/step - loss: 0.0174 - accuracy: 0.9979
# Epoch 3/5
# 2849/2849 [==============================] - 9s 3ms/step - loss: 0.0224 - accuracy: 0.9982
# Epoch 4/5
# 2849/2849 [==============================] - 9s 3ms/step - loss: 0.0138 - accuracy: 0.9982
# Epoch 5/5
# 2849/2849 [==============================] - 9s 3ms/step - loss: 0.0769 - accuracy: 0.9977

# %% [markdown]
# 492 / 284315 = 0.001727485630620034 => 0.0017%의 확률이므로 0으로 찍어도 최소 99.82%는 나온다.<br>
# 해야하는 것 :
# 1. 492를 뻥튀기 <br>-> 여러 번 반복한다
#
# => 데이터가 일그러진다 조작된다 -> 영향이 가지 않을까?
# -> 일리가 있다. 하지만 대체할 수 없기 때문에 시도를 해 보는것이다
# ==> 알수 있는것 : 블랙박스다(= 모른다)<br>
#
# 2. 28만개를 좀 줄인다.
# 3. 이상치를 걸러내본다.

# %%
def plot_metrics(history):
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    metrics = ['loss', 'accuracy']
    plt.rcParams["figure.figsize"] = (14,10)
    for n, metrics in enumerate(metrics):
        name = metrics.replace("_"," ").capitalize()
        plt.subplot(2,2,n+1)
        plt.plot(history.epoch, history.history[metrics],color=colors[0],label='Train')
        #plt.plot(history.epoch, history.history['val_'+ metrics],
        #     color=colors[0], linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metrics == 'loss':
            plt.ylim([0, plt.ylim()[1]])
        elif metrics == 'accuracy':
            plt.ylim([0.9,1.1])
        else:
            plt.ylim([0,1])
        plt.legend()

# %%
plot_metrics(history_1)

# %% [markdown]
# 손실, 정확도,

# %% [markdown]
# 실질적으로 여기 아래 부분을 복사를 하던 해서 커스텀 하시면 됩니다,

# %% [markdown]
# **정상 vs 비정상(사기) 데이터 구분하기**<br>
# 추후 진행

# %%
df_2 = df.drop(columns=['Amount'])

# %%
fraud = []
non_fraud = [] # 건드려야할 데이터.
for data in df_2.values:
    if data[-1] == 1:
        fraud.append(data)
    else:
        non_fraud.append(data)

print(len(fraud))
print(len(non_fraud))
# Out:
# 492
# 284315

# %%
fraud[0]
# Out:
# array([ 4.06000000e+02, -2.31222654e+00,  1.95199201e+00, -1.60985073e+00,
#         3.99790559e+00, -5.22187865e-01, -1.42654532e+00, -2.53738731e+00,
#         1.39165725e+00, -2.77008928e+00, -2.77227214e+00,  3.20203321e+00,
#        -2.89990739e+00, -5.95221881e-01, -4.28925378e+00,  3.89724120e-01,
#        -1.14074718e+00, -2.83005567e+00, -1.68224682e-02,  4.16955705e-01,
#         1.26910559e-01,  5.17232371e-01, -3.50493686e-02, -4.65211076e-01,
#         3.20198199e-01,  4.45191675e-02,  1.77839798e-01,  2.61145003e-01,
#        -1.43275875e-01,  0.00000000e+00,  1.00000000e+00])

# %% [markdown]
# 데이터 관리

# %%
# 사기 데이터 늘리기
for i in range(2):
    l = len(fraud)
    for index in range(l):
        fraud.append(fraud[index])
print(len(fraud))
# Out:
# 1968

# %%
p_data = []
for data in fraud:
    p_data.append(data)
        
for i in range(1000):# 1. 값 = 비율 조절. 돌려보는 (정상데이터)
    p_data.append(non_fraud[i])

print(len(p_data)) #사기데이터 + 정상데이터
# Out:
# 2968

# %% [markdown]
# 정상 : 91% vs 비정상 : 9%

# %% [markdown]
# 데이터 스플릿<br>
# 85:15

# %%
p_data = np.array(p_data)

x = p_data[:,:-1]

y = p_data[:,-1]

# %%
print(len(x[0]))
# Out:
# 30

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
model = Sequential() # 2. 이거 만들어보기.
model.add(Dense(100, input_dim=30, activation='relu' ))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(25, activation='relu'))
model.add(Dense(13, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),tf.keras.metrics.Recall(name='recall')])
#tf.keras.metrics.Precision(name=
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 100)               3100
# _________________________________________________________________
# dense_16 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 25)                1275
# _________________________________________________________________
# dense_18 (Dense)             (None, 13)                338
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 14
# =================================================================
# Total params: 9,777
# Trainable params: 9,777
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# 학습 진행

# %%
# 모델을 실행합니다.
history_2 = model.fit(X_train, y_train, epochs=20, batch_size=100, validation_data=(X_test,y_test)) # batch_size
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 32ms/step - loss: 219.0114 - accuracy: 0.5806 - precision: 0.6446 - recall: 0.7657 - val_loss: 11.0784 - val_accuracy: 0.6751 - val_precision: 0.6751 - val_recall: 1.0000
# Epoch 2/20
# 24/24 [==============================] - 0s 5ms/step - loss: 11.1564 - accuracy: 0.6665 - precision: 0.6659 - recall: 1.0000 - val_loss: 6.0215 - val_accuracy: 0.6751 - val_precision: 0.6751 - val_recall: 1.0000
# Epoch 3/20
# 24/24 [==============================] - 0s 4ms/step - loss: 9.3058 - accuracy: 0.6507 - precision: 0.6501 - recall: 0.9964 - val_loss: 4.5452 - val_accuracy: 0.6801 - val_precision: 0.6785 - val_recall: 1.0000
# Epoch 4/20
# 24/24 [==============================] - 0s 5ms/step - loss: 5.8567 - accuracy: 0.6731 - precision: 0.6720 - recall: 0.9948 - val_loss: 3.4001 - val_accuracy: 0.6852 - val_precision: 0.6820 - val_recall: 1.0000
# Epoch 5/20
# 24/24 [==============================] - 0s 5ms/step - loss: 4.6829 - accuracy: 0.6738 - precision: 0.6696 - recall: 0.9970 - val_loss: 3.5161 - val_accuracy: 0.6886 - val_precision: 0.6843 - val_recall: 1.0000
# Epoch 6/20
# 24/24 [==============================] - 0s 5ms/step - loss: 3.7829 - accuracy: 0.6826 - precision: 0.6743 - recall: 0.9975 - val_loss: 3.1462 - val_accuracy: 0.6953 - val_precision: 0.6890 - val_recall: 1.0000
# Epoch 7/20
# 24/24 [==============================] - 0s 5ms/step - loss: 4.7600 - accuracy: 0.7034 - precision: 0.6939 - recall: 0.9942 - val_loss: 3.3145 - val_accuracy: 0.6919 - val_precision: 0.6866 - val_recall: 1.0000
# Epoch 8/20
# 24/24 [==============================] - 0s 5ms/step - loss: 4.2075 - accuracy: 0.6703 - precision: 0.6648 - recall: 1.0000 - val_loss: 1.7026 - val_accuracy: 0.7020 - val_precision: 0.6938 - val_recall: 1.0000
# Epoch 9/20
# 24/24 [==============================] - 0s 5ms/step - loss: 2.3594 - accuracy: 0.7080 - precision: 0.6985 - recall: 0.9958 - val_loss: 1.8063 - val_accuracy: 0.7088 - val_precision: 0.6986 - val_recall: 1.0000
# Epoch 10/20
# 24/24 [==============================] - 0s 4ms/step - loss: 2.7155 - accuracy: 0.6862 - precision: 0.6706 - recall: 0.9986 - val_loss: 0.9239 - val_accuracy: 0.7306 - val_precision: 0.7148 - val_recall: 1.0000
# Epoch 11/20
# 24/24 [==============================] - 0s 5ms/step - loss: 1.4933 - accuracy: 0.7236 - precision: 0.7006 - recall: 0.9985 - val_loss: 1.0896 - val_accuracy: 0.7441 - val_precision: 0.7251 - val_recall: 1.0000
# Epoch 12/20
# 24/24 [==============================] - 0s 4ms/step - loss: 1.7036 - accuracy: 0.7411 - precision: 0.7187 - recall: 0.9977 - val_loss: 0.7337 - val_accuracy: 0.7441 - val_precision: 0.7251 - val_recall: 1.0000
# Epoch 13/20
# 24/24 [==============================] - 0s 4ms/step - loss: 1.5925 - accuracy: 0.7553 - precision: 0.7300 - recall: 0.9978 - val_loss: 0.6607 - val_accuracy: 0.7508 - val_precision: 0.7304 - val_recall: 1.0000
# Epoch 14/20
# 24/24 [==============================] - 0s 5ms/step - loss: 1.6356 - accuracy: 0.7328 - precision: 0.7129 - recall: 0.9999 - val_loss: 0.0936 - val_accuracy: 0.9966 - val_precision: 1.0000 - val_recall: 0.9950
# Epoch 15/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.9065 - accuracy: 0.7729 - precision: 0.7475 - recall: 0.9933 - val_loss: 0.1344 - val_accuracy: 0.9545 - val_precision: 0.9410 - val_recall: 0.9950
# Epoch 16/20
# 24/24 [==============================] - 0s 4ms/step - loss: 1.0471 - accuracy: 0.7820 - precision: 0.7543 - recall: 0.9977 - val_loss: 1.3879 - val_accuracy: 0.7357 - val_precision: 0.7186 - val_recall: 1.0000
# Epoch 17/20
# 24/24 [==============================] - 0s 5ms/step - loss: 2.2224 - accuracy: 0.7105 - precision: 0.6927 - recall: 1.0000 - val_loss: 0.7191 - val_accuracy: 0.7593 - val_precision: 0.7371 - val_recall: 1.0000
# Epoch 18/20
# 24/24 [==============================] - 0s 5ms/step - loss: 1.2631 - accuracy: 0.7588 - precision: 0.7349 - recall: 0.9990 - val_loss: 0.1946 - val_accuracy: 0.8822 - val_precision: 0.8529 - val_recall: 0.9975
# Epoch 19/20
# 24/24 [==============================] - 0s 4ms/step - loss: 0.8576 - accuracy: 0.7864 - precision: 0.7579 - recall: 0.9985 - val_loss: 0.1361 - val_accuracy: 0.9360 - val_precision: 0.9172 - val_recall: 0.9950
# Epoch 20/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5625 - accuracy: 0.8120 - precision: 0.7826 - recall: 0.9972 - val_loss: 0.0821 - val_accuracy: 0.9966 - val_precision: 1.0000 - val_recall: 0.9950

# %%
def plot_metrics(history):
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    metrics = ['loss', 'accuracy']
    plt.rcParams["figure.figsize"] = (14,10)
    for n, metrics in enumerate(metrics):
        name = metrics.replace("_"," ").capitalize()
        plt.subplot(2,2,n+1)
        plt.plot(history.epoch, history.history[metrics],color=colors[0],label='Train')
        plt.plot(history.epoch, history.history['val_'+ metrics],
            color=colors[0], linestyle="--", label='Test')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metrics == 'loss':
            plt.ylim([0, plt.ylim()[1]])
        elif metrics == 'accuracy':
            plt.ylim([0.5,1])
        else:
            plt.ylim([0,1])
        plt.legend()

# %%
plot_metrics(history_2)

# %% [markdown]
# # TO DO

# %% [markdown]
# 1. 데이터 관리에 fraud가 아닌것의 개수(비율) 조절해서 돌려보기<br>
# 2. 나만의 모델 만들어보기. => 추가 삭제 개수 늘림 줄임 다 가능
