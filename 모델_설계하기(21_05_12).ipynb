# %% [markdown]
# <a href="https://colab.research.google.com/github/zzickso/DeepLearning/blob/main/%EB%AA%A8%EB%8D%B8_%EC%84%A4%EA%B3%84%ED%95%98%EA%B8%B0(21_05_12).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive') #코랩 파일 드라이브에서 가져오기
# Out:
# Mounted at /content/drive

# %%
# 딥러닝을 구동하는 데 필요한 케라스 함수 호출
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 필요한 라이브러리 불러오기
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# 실행할 때마다 같은 결과를 출력하기 위해 설정하는 부분
np.random.seed(3)
tf.random.set_seed(3)

# 준비된 수술 환자 데이터를 불러오기
Data_set = np.loadtxt("/content/drive/MyDrive/test/ThoraricSurgery.csv", delimiter=",")

# 환자의 기록과 수술 결과를 X와 Y로 구분하여 저장
X = Data_set[:,0:17]
Y = Data_set[:,17]

# 딥러닝 구조를 결정(모델을 설정하고 실행)
model = Sequential()
model.add(Dense(30, input_dim=17, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 딥러닝 실행
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 1s 1ms/step - loss: 0.8781 - accuracy: 0.7774
# Epoch 2/100
# 47/47 [==============================] - 0s 957us/step - loss: 0.4637 - accuracy: 0.8707
# Epoch 3/100
# 47/47 [==============================] - 0s 931us/step - loss: 0.4652 - accuracy: 0.8347
# Epoch 4/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.5176 - accuracy: 0.8405
# Epoch 5/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4461 - accuracy: 0.8570
# Epoch 6/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4391 - accuracy: 0.8523
# Epoch 7/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4616 - accuracy: 0.8443
# Epoch 8/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4523 - accuracy: 0.8447
# Epoch 9/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3877 - accuracy: 0.8618
# Epoch 10/100
# ...
